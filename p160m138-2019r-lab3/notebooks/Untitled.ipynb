# %%
import os
import pandas as pd
from plotnine import *
path = '/data/raw/'
fileName = 'bank-full.csv'
currentPath = os.path.dirname(os.path.realpath("."))
file = open(f'{currentPath}{path}{fileName}', 'r')
lines = file.readlines()
firstLine = True
values = {}
labels = []
for line in lines:
    splitValues = line.split(';')
    if firstLine:
        for splitValue in splitValues:
            splitValue = splitValue.replace('"', '').replace('\n', '')
            labels.append(splitValue)
            values[splitValue] = []
        firstLine = False
    else:
        for index, splitValue in enumerate(splitValues):
            splitValue = splitValue.replace('"', '').replace('\n', '')
            values[labels[index]].append(splitValue)
df = pd.DataFrame(data=values)
for label in labels:
    plot = (ggplot(df, aes(x=label)) + geom_histogram() + ggtitle("Histogram of " + label))
    fileName = f"Histogram_{label}"
    ggsave(plot, filename=fileName, path=currentPath)
    
df.describe()
# Out:
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: /home/user/Desktop/2lab/p160m138-2019r-lab2/p160m138-2019r-lab2/Histogram_age
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 91'. Pick better value with 'binwidth'.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: /home/user/Desktop/2lab/p160m138-2019r-lab2/p160m138-2019r-lab2/Histogram_job
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 33'. Pick better value with 'binwidth'.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: /home/user/Desktop/2lab/p160m138-2019r-lab2/p160m138-2019r-lab2/Histogram_marital
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 36'. Pick better value with 'binwidth'.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: /home/user/Desktop/2lab/p160m138-2019r-lab2/p160m138-2019r-lab2/Histogram_education
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 54'. Pick better value with 'binwidth'.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: /home/user/Desktop/2lab/p160m138-2019r-lab2/p160m138-2019r-lab2/Histogram_default
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 213'. Pick better value with 'binwidth'.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: /home/user/Desktop/2lab/p160m138-2019r-lab2/p160m138-2019r-lab2/Histogram_balance
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 34'. Pick better value with 'binwidth'.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: /home/user/Desktop/2lab/p160m138-2019r-lab2/p160m138-2019r-lab2/Histogram_housing
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 18'. Pick better value with 'binwidth'.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: /home/user/Desktop/2lab/p160m138-2019r-lab2/p160m138-2019r-lab2/Histogram_loan
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 213'. Pick better value with 'binwidth'.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: /home/user/Desktop/2lab/p160m138-2019r-lab2/p160m138-2019r-lab2/Histogram_contact
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 18'. Pick better value with 'binwidth'.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: /home/user/Desktop/2lab/p160m138-2019r-lab2/p160m138-2019r-lab2/Histogram_day
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 36'. Pick better value with 'binwidth'.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: /home/user/Desktop/2lab/p160m138-2019r-lab2/p160m138-2019r-lab2/Histogram_month
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 40'. Pick better value with 'binwidth'.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: /home/user/Desktop/2lab/p160m138-2019r-lab2/p160m138-2019r-lab2/Histogram_duration
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 53'. Pick better value with 'binwidth'.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: /home/user/Desktop/2lab/p160m138-2019r-lab2/p160m138-2019r-lab2/Histogram_campaign
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 39'. Pick better value with 'binwidth'.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: /home/user/Desktop/2lab/p160m138-2019r-lab2/p160m138-2019r-lab2/Histogram_pdays
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 213'. Pick better value with 'binwidth'.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: /home/user/Desktop/2lab/p160m138-2019r-lab2/p160m138-2019r-lab2/Histogram_previous
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 213'. Pick better value with 'binwidth'.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: /home/user/Desktop/2lab/p160m138-2019r-lab2/p160m138-2019r-lab2/Histogram_poutcome
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 213'. Pick better value with 'binwidth'.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: /home/user/Desktop/2lab/p160m138-2019r-lab2/p160m138-2019r-lab2/Histogram_y
# /home/user/anaconda3/envs/bank-tele/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 213'. Pick better value with 'binwidth'.

# %%
import os
import pandas as pd
from plotnine import *
from sklearn import preprocessing
def drawHistograms():
    for label in labels:
        plot = (ggplot(df, aes(x=label)) + geom_histogram() + ggtitle("Histogram of " + label))
        fileName = f"Histogram_{label}"
        ggsave(plot, filename=fileName, path=currentPath) 
path = '/data/raw/'
fileName = 'bank-full.csv'
currentPath = os.path.dirname(os.path.realpath("."))
file = open(f'{currentPath}{path}{fileName}', 'r')
lines = file.readlines()
firstLine = True
values = {}
labels = []
for line in lines:
    splitValues = line.split(';')
    if firstLine:
        for splitValue in splitValues:
            splitValue = splitValue.replace('"', '').replace('\n', '')
            labels.append(splitValue)
            values[splitValue] = []
        firstLine = False
    else:
        for index, splitValue in enumerate(splitValues):
            splitValue = splitValue.replace('"', '').replace('\n', '')
            values[labels[index]].append(splitValue)
df = pd.DataFrame(data=values)
df.describe()
# Out:
#           age          job  marital  education default balance housing   loan  \
# count   45211        45211    45211      45211   45211   45211   45211  45211
# unique     77           12        3          4       2    7168       2      2
# top        32  blue-collar  married  secondary      no       0     yes     no
# freq     2085         9732    27214      23202   44396    3514   25130  37967
#
#          contact    day  month duration campaign  pdays previous poutcome  \
# count      45211  45211  45211    45211    45211  45211    45211    45211
# unique         3     31     12     1573       48    559       41        4
# top     cellular     20    may      124        1     -1        0  unknown
# freq       29285   2752  13766      188    17544  36954    36954    36959
#
#             y
# count   45211
# unique      2
# top        no
# freq    39922
